# %%
# !pip install https://github.com/ipython-contrib/jupyter_contrib_nbextensions/tarball/master
# !pip install jupyter_nbextensions_configurator
# !jupyter contrib nbextension install --user
# !jupyter nbextensions_configurator enable --user
# Out:
# Collecting https://github.com/ipython-contrib/jupyter_contrib_nbextensions/tarball/master
#   Downloading https://github.com/ipython-contrib/jupyter_contrib_nbextensions/tarball/master
# Requirement already satisfied: ipython_genutils in c:\users\saus\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions==0.3.3)
# Collecting jupyter_contrib_core>=0.3.3 (from jupyter-contrib-nbextensions==0.3.3)
#   Downloading jupyter_contrib_core-0.3.3-py2.py3-none-any.whl
# Requirement already satisfied: jupyter_core in c:\users\saus\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions==0.3.3)
# Collecting jupyter_highlight_selected_word>=0.0.10 (from jupyter-contrib-nbextensions==0.3.3)
#   Downloading jupyter_highlight_selected_word-0.1.0-py2.py3-none-any.whl
# Collecting jupyter_latex_envs>=1.3.8 (from jupyter-contrib-nbextensions==0.3.3)
#   Downloading jupyter_latex_envs-1.4.1.tar.gz (793kB)
# Collecting jupyter_nbextensions_configurator>=0.2.8 (from jupyter-contrib-nbextensions==0.3.3)
#   Downloading jupyter_nbextensions_configurator-0.2.8-py2.py3-none-any.whl (465kB)
# Requirement already satisfied: nbconvert>=4.2 in c:\users\saus\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions==0.3.3)
# Requirement already satisfied: notebook>=4.0 in c:\users\saus\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions==0.3.3)
# Requirement already satisfied: pyyaml in c:\users\saus\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions==0.3.3)
# Requirement already satisfied: tornado in c:\users\saus\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions==0.3.3)
# Requirement already satisfied: traitlets>=4.1 in c:\users\saus\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions==0.3.3)
# Requirement already satisfied: lxml>=3.8.0 in c:\users\saus\anaconda3\lib\site-packages (from jupyter-contrib-nbextensions==0.3.3)
# Requirement already satisfied: setuptools in c:\users\saus\anaconda3\lib\site-packages (from jupyter_contrib_core>=0.3.3->jupyter-contrib-nbextensions==0.3.3)
# Requirement already satisfied: ipython in c:\users\saus\anaconda3\lib\site-packages (from jupyter_latex_envs>=1.3.8->jupyter-contrib-nbextensions==0.3.3)
# Requirement already satisfied: mistune>=0.7.4 in c:\users\saus\anaconda3\lib\site-packages (from nbconvert>=4.2->jupyter-contrib-nbextensions==0.3.3)
# Requirement already satisfied: jinja2 in c:\users\saus\anaconda3\lib\site-packages (from nbconvert>=4.2->jupyter-contrib-nbextensions==0.3.3)
# Requirement already satisfied: pygments in c:\users\saus\anaconda3\lib\site-packages (from nbconvert>=4.2->jupyter-contrib-nbextensions==0.3.3)
# Requirement already satisfied: nbformat>=4.4 in c:\users\saus\anaconda3\lib\site-packages (from nbconvert>=4.2->jupyter-contrib-nbextensions==0.3.3)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\saus\anaconda3\lib\site-packages (from nbconvert>=4.2->jupyter-contrib-nbextensions==0.3.3)
# Requirement already satisfied: bleach in c:\users\saus\anaconda3\lib\site-packages (from nbconvert>=4.2->jupyter-contrib-nbextensions==0.3.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\saus\anaconda3\lib\site-packages (from nbconvert>=4.2->jupyter-contrib-nbextensions==0.3.3)
# Requirement already satisfied: testpath in c:\users\saus\anaconda3\lib\site-packages (from nbconvert>=4.2->jupyter-contrib-nbextensions==0.3.3)
# Requirement already satisfied: six in c:\users\saus\anaconda3\lib\site-packages (from traitlets>=4.1->jupyter-contrib-nbextensions==0.3.3)
# Requirement already satisfied: decorator in c:\users\saus\anaconda3\lib\site-packages (from traitlets>=4.1->jupyter-contrib-nbextensions==0.3.3)
# Requirement already satisfied: jedi>=0.10 in c:\users\saus\anaconda3\lib\site-packages (from ipython->jupyter_latex_envs>=1.3.8->jupyter-contrib-nbextensions==0.3.3)
# Requirement already satisfied: pickleshare in c:\users\saus\anaconda3\lib\site-packages (from ipython->jupyter_latex_envs>=1.3.8->jupyter-contrib-nbextensions==0.3.3)
# Requirement already satisfied: simplegeneric>0.8 in c:\users\saus\anaconda3\lib\site-packages (from ipython->jupyter_latex_envs>=1.3.8->jupyter-contrib-nbextensions==0.3.3)
# Requirement already satisfied: prompt_toolkit<2.0.0,>=1.0.4 in c:\users\saus\anaconda3\lib\site-packages (from ipython->jupyter_latex_envs>=1.3.8->jupyter-contrib-nbextensions==0.3.3)
# Requirement already satisfied: colorama in c:\users\saus\anaconda3\lib\site-packages (from ipython->jupyter_latex_envs>=1.3.8->jupyter-contrib-nbextensions==0.3.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\saus\anaconda3\lib\site-packages (from jinja2->nbconvert>=4.2->jupyter-contrib-nbextensions==0.3.3)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\saus\anaconda3\lib\site-packages (from nbformat>=4.4->nbconvert>=4.2->jupyter-contrib-nbextensions==0.3.3)
# Requirement already satisfied: html5lib!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8,>=0.99999999pre in c:\users\saus\anaconda3\lib\site-packages (from bleach->nbconvert>=4.2->jupyter-contrib-nbextensions==0.3.3)
# Requirement already satisfied: parso==0.1.* in c:\users\saus\anaconda3\lib\site-packages (from jedi>=0.10->ipython->jupyter_latex_envs>=1.3.8->jupyter-contrib-nbextensions==0.3.3)
# Requirement already satisfied: wcwidth in c:\users\saus\anaconda3\lib\site-packages (from prompt_toolkit<2.0.0,>=1.0.4->ipython->jupyter_latex_envs>=1.3.8->jupyter-contrib-nbextensions==0.3.3)
# Requirement already satisfied: webencodings in c:\users\saus\anaconda3\lib\site-packages (from html5lib!=1.0b1,!=1.0b2,!=1.0b3,!=1.0b4,!=1.0b5,!=1.0b6,!=1.0b7,!=1.0b8,>=0.99999999pre->bleach->nbconvert>=4.2->jupyter-contrib-nbextensions==0.3.3)
# Building wheels for collected packages: jupyter-latex-envs
#   Running setup.py bdist_wheel for jupyter-latex-envs: started
#   Running setup.py bdist_wheel for jupyter-latex-envs: finished with status 'done'
#   Stored in directory: C:\Users\saus\AppData\Local\pip\Cache\wheels\c4\6c\12\312460b777568482fbf308ab45154a573172ac33da9c91cf83
# Successfully built jupyter-latex-envs
# Installing collected packages: jupyter-contrib-core, jupyter-highlight-selected-word, jupyter-latex-envs, jupyter-nbextensions-configurator, jupyter-contrib-nbextensions
#   Running setup.py install for jupyter-contrib-nbextensions: started
#     Running setup.py install for jupyter-contrib-nbextensions: finished with status 'done'
# Successfully installed jupyter-contrib-core-0.3.3 jupyter-contrib-nbextensions-0.3.3 jupyter-highlight-selected-word-0.1.0 jupyter-latex-envs-1.4.1 jupyter-nbextensions-configurator-0.2.8
# Requirement already satisfied: jupyter_nbextensions_configurator in c:\users\saus\anaconda3\lib\site-packages
# Requirement already satisfied: jupyter-contrib-core>=0.3.3 in c:\users\saus\anaconda3\lib\site-packages (from jupyter_nbextensions_configurator)
# Requirement already satisfied: tornado in c:\users\saus\anaconda3\lib\site-packages (from jupyter_nbextensions_configurator)
# Requirement already satisfied: pyyaml in c:\users\saus\anaconda3\lib\site-packages (from jupyter_nbextensions_configurator)
# Requirement already satisfied: traitlets in c:\users\saus\anaconda3\lib\site-packages (from jupyter_nbextensions_configurator)
# Requirement already satisfied: jupyter-core in c:\users\saus\anaconda3\lib\site-packages (from jupyter_nbextensions_configurator)
# Requirement already satisfied: notebook>=4.0 in c:\users\saus\anaconda3\lib\site-packages (from jupyter_nbextensions_configurator)
# Requirement already satisfied: setuptools in c:\users\saus\anaconda3\lib\site-packages (from jupyter-contrib-core>=0.3.3->jupyter_nbextensions_configurator)
# Requirement already satisfied: ipython_genutils in c:\users\saus\anaconda3\lib\site-packages (from traitlets->jupyter_nbextensions_configurator)
# Requirement already satisfied: six in c:\users\saus\anaconda3\lib\site-packages (from traitlets->jupyter_nbextensions_configurator)
# Requirement already satisfied: decorator in c:\users\saus\anaconda3\lib\site-packages (from traitlets->jupyter_nbextensions_configurator)
# [I 16:46:57 InstallContribNbextensionsApp] jupyter contrib nbextension install --user
# [W 16:46:57 InstallContribNbextensionsApp] Error: Cannot configure while the Jupyter notebook server is running
# [I 16:46:57 InstallContribNbextensionsApp] To perform actions even while a notebook server is running,you may use the flag
#     --skip-running-check
# Traceback (most recent call last):
#   File "c:\users\saus\anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "c:\users\saus\anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\saus\Anaconda3\Scripts\jupyter-contrib.EXE\__main__.py", line 9, in <module>
#   File "c:\users\saus\anaconda3\lib\site-packages\jupyter_core\application.py", line 266, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "c:\users\saus\anaconda3\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "c:\users\saus\anaconda3\lib\site-packages\jupyter_contrib_core\application.py", line 50, in start
#     super(JupyterContribApp, self).start()
#   File "c:\users\saus\anaconda3\lib\site-packages\jupyter_core\application.py", line 255, in start
#     self.subapp.start()
#   File "c:\users\saus\anaconda3\lib\site-packages\jupyter_contrib_nbextensions\application.py", line 226, in start
#     super(ContribNbextensionsApp, self).start()
#   File "c:\users\saus\anaconda3\lib\site-packages\jupyter_core\application.py", line 255, in start
#     self.subapp.start()
#   File "c:\users\saus\anaconda3\lib\site-packages\jupyter_contrib_nbextensions\application.py", line 173, in start
#     toggle_install_files(self._toggle_value, **kwargs_files)
#   File "c:\users\saus\anaconda3\lib\site-packages\jupyter_contrib_nbextensions\install.py", line 60, in toggle_install_files
#     'Cannot configure while the Jupyter notebook server is running')
# jupyter_contrib_nbextensions.install.NotebookRunningError: Cannot configure while the Jupyter notebook server is running
# Enabling: jupyter_nbextensions_configurator
# - Writing config: C:\Users\saus\.jupyter
#     - Validating...
#       jupyter_nbextensions_configurator  ok
# Enabling notebook nbextension nbextensions_configurator/config_menu/main...
# Enabling tree nbextension nbextensions_configurator/tree_tab/main...
